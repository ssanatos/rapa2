# %% [markdown]
# # 8.네이버 오픈API 사용하기

# %% [markdown]
# ### 책 검색
#  - 책검색 https://book.naver.com/
#  - 네이버오픈API https://developers.naver.com/products/intro/plan/
#  - API사용신청 https://developers.naver.com/apps/#/register

# %%
import urllib.request
import json

#------------------------------------
# 네이버 애플리케이션 등록 정보
#------------------------------------
Client_ID = "WlIpA7IkqcaBRP6XKyUk"  # 자신의 client id 
Client_Secret = "pIew6Mp_Fr"    # 자신의 client secret

#------------------------------------
#  검색어 입력받아 네이버검색 url 설정
#------------------------------------
# 검색어 입력
title = input("검색 도서명: ")

# url설정
url = "https://openapi.naver.com/v1/search/book.json"
option = "&display=3&sort=count"    
query = "?query="+urllib.parse.quote(title)
url_query = url + query + option
    
#Open API 검색 요청 개체 설정
request = urllib.request.Request(url_query)
request.add_header("X-Naver-Client-Id", Client_ID)
request.add_header("X-Naver-Client-Secret", Client_Secret)

#------------------------------------
# 검색 요청 및 처리
#------------------------------------
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode == 200):
    result = response.read().decode('utf-8')
    #print(result) # result에 어떤 값이 들어 있는지 확인해 보기
else:
    print("검색에 실패하였습니다.")
    exit()

#------------------------------------
# 검색 결과 parsing 해서 보기좋게 출력하기
#------------------------------------
j_result = json.loads(result)   #검색 결과를 json타입으로 보여주기
if j_result == None:
    print("json.loads 실패하였습니다.")
    exit()
#print(j_result) # j_result에 어떤 값이 들어 있는지 확인해 보기
 
# j_result의 결과 중 도서 정보가 담긴 items 항목의 내용을 parsing한다.
for item in j_result['items']:
    print("\n제목: " + item['title'])
    print("저자: " + item['author'])
    print("설명: " + item['description'])
    print("url: " + item['link'])
    print("\n")
# Out:
# 검색 도서명: 드론
# {
# "lastBuildDate": "Mon, 06 Sep 2021 17:35:34 +0900",
# "total": 2500,
# "start": 1,
# "display": 3,
# "items": [
# {
# "title": "2022 최적합 <b>드론</b>(무인멀티콥터) 조종자 자격 필기 (무료 동영상 강의 제공)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=20685378",
# "image": "https://bookthumb-phinf.pstatic.net/cover/206/853/20685378.jpg?type=m1&udate=20210630",
# "author": "박익범|한대희|박병찬|박인순|곽병태|강호식|장태환|김용덕",
# "price": "20000",
# "discount": "18000",
# "publisher": "성안당",
# "pubdate": "20210628",
# "isbn": "8931550448 9788931550443",
# "description": "■ 책의 특징\n- 한국교통안전공단의 새로운 출제기준(2021.3.1)을 적용하였습니다.\n- 무인비행장치 조종자의 자격 및 전문교육기관 지정기준(국토교통부고시, 2021.6.14) 등 최근 개정된 항공법규를 반영하였습니다.\n- 경륜 있는 저자들이 분야별로 정리.감수하여 출제 비중이 높은 내용으로 구성하였습니다.... "
#
# },
# {
# "title": "Why? <b>드론</b>",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=14571750",
# "image": "https://bookthumb-phinf.pstatic.net/cover/145/717/14571750.jpg?type=m1&udate=20190223",
# "author": "조영선",
# "price": "12800",
# "discount": "11520",
# "publisher": "예림당",
# "pubdate": "20190215",
# "isbn": "8930237703 9788930237703",
# "description": "<b>드론</b>의 가능성에 상상력을 더해 보자.\n‘윙~’하는 소리와 함께 순식간에 하늘로 솟구치는 <b>드론</b>. 중력을 무시하듯 허공에서 자유자재로 움직이는 모습은... <b>드론</b>이 대중에게 알려진 것은 비교적 최근의 일이지만, 그 역사는 생각보다 길다. 제1차 세계 대전 당시 먼 거리의 적을 공격하기 위해 만들었던 ‘비행... "
#
# },
# {
# "title": "신 <b>드론</b> 무인멀티콥터 <b>드론</b>자격증필기 한권으로 끝내기 (2018 <b>드론</b>)",
# "link": "http://book.naver.com/bookdb/book_detail.php?bid=13423821",
# "image": "https://bookthumb-phinf.pstatic.net/cover/134/238/13423821.jpg?type=m1&udate=20191107",
# "author": "시대<b>드론</b>센터|서일수|장경석",
# "price": "33000",
# "discount": "",
# "publisher": "시대고시기획<b>드론</b>센터",
# "pubdate": "20180406",
# "isbn": "1125445335 9791125445333",
# "description": "국내 최고 <b>드론</b> 전문가 집필!!\n본 도서는 한국교통안전공단에서 시행하는 초경량비행장치(<b>드론</b>) 조종자 자격증 학과시험(필기시험) 대비서로 공단에서 발표한 2018년 변경된 학과시험 출제기준을 완벽 반영하였습니다. 출제기준을 철저하게 분석하여 정리한 핵심이론을 단원별로 수록하였으며, 중요한... "
#
# }
# ]
# }
#
#
# 제목: 2022 최적합 <b>드론</b>(무인멀티콥터) 조종자 자격 필기 (무료 동영상 강의 제공)
# 저자: 박익범|한대희|박병찬|박인순|곽병태|강호식|장태환|김용덕
# 설명: ■ 책의 특징
# - 한국교통안전공단의 새로운 출제기준(2021.3.1)을 적용하였습니다.
# - 무인비행장치 조종자의 자격 및 전문교육기관 지정기준(국토교통부고시, 2021.6.14) 등 최근 개정된 항공법규를 반영하였습니다.
# - 경륜 있는 저자들이 분야별로 정리.감수하여 출제 비중이 높은 내용으로 구성하였습니다....
# url: http://book.naver.com/bookdb/book_detail.php?bid=20685378
#
#
#
# 제목: Why? <b>드론</b>
# 저자: 조영선
# 설명: <b>드론</b>의 가능성에 상상력을 더해 보자.
# ‘윙~’하는 소리와 함께 순식간에 하늘로 솟구치는 <b>드론</b>. 중력을 무시하듯 허공에서 자유자재로 움직이는 모습은... <b>드론</b>이 대중에게 알려진 것은 비교적 최근의 일이지만, 그 역사는 생각보다 길다. 제1차 세계 대전 당시 먼 거리의 적을 공격하기 위해 만들었던 ‘비행...
# url: http://book.naver.com/bookdb/book_detail.php?bid=14571750
#
#
#
# 제목: 신 <b>드론</b> 무인멀티콥터 <b>드론</b>자격증필기 한권으로 끝내기 (2018 <b>드론</b>)
# 저자: 시대<b>드론</b>센터|서일수|장경석
# 설명: 국내 최고 <b>드론</b> 전문가 집필!!
# 본 도서는 한국교통안전공단에서 시행하는 초경량비행장치(<b>드론</b>) 조종자 자격증 학과시험(필기시험) 대비서로 공단에서 발표한 2018년 변경된 학과시험 출제기준을 완벽 반영하였습니다. 출제기준을 철저하게 분석하여 정리한 핵심이론을 단원별로 수록하였으며, 중요한...
# url: http://book.naver.com/bookdb/book_detail.php?bid=13423821
